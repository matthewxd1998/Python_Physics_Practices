# %%
#1D Kinematics and Loops

# %%
x = 0
t = 0
i = 0
v = 0.45
dt = 0.25

# %%
while t <= 1.5:
    print("t{} = {}s".format(i, t))
    print("x{} = {}m".format(i, x))
    if t < 1.5:
        t += dt
        x += v*dt
        i +=1
    elif t >= 1.5:
        break
# Out:
# t0 = 0s
# x0 = 0m
# t1 = 0.25s
# x1 = 0.1125m
# t2 = 0.5s
# x2 = 0.225m
# t3 = 0.75s
# x3 = 0.3375m
# t4 = 1.0s
# x4 = 0.45m
# t5 = 1.25s
# x5 = 0.5625m
# t6 = 1.5s
# x6 = 0.675m

# %%
#Where will the cart be at 2.2 seconds?
x = 0
t = 0
i = 0
v = 0.45
dt = 0.1

while t < 2.3:
    print("t{} = {}s".format(i, t))
    print("x{} = {}m".format(i, x))
    if t < 2.3:
        t += dt
        x += v*dt
        i += 1
    elif t >= 2.3:
        break
# Out:
# t0 = 0s
# x0 = 0m
# t1 = 0.1s
# x1 = 0.045000000000000005m
# t2 = 0.2s
# x2 = 0.09000000000000001m
# t3 = 0.30000000000000004s
# x3 = 0.135m
# t4 = 0.4s
# x4 = 0.18000000000000002m
# t5 = 0.5s
# x5 = 0.22500000000000003m
# t6 = 0.6s
# x6 = 0.27m
# t7 = 0.7s
# x7 = 0.315m
# t8 = 0.7999999999999999s
# x8 = 0.36m
# t9 = 0.8999999999999999s
# x9 = 0.40499999999999997m
# t10 = 0.9999999999999999s
# x10 = 0.44999999999999996m
# t11 = 1.0999999999999999s
# x11 = 0.49499999999999994m
# t12 = 1.2s
# x12 = 0.5399999999999999m
# t13 = 1.3s
# x13 = 0.585m
# t14 = 1.4000000000000001s
# x14 = 0.63m
# t15 = 1.5000000000000002s
# x15 = 0.675m
# t16 = 1.6000000000000003s
# x16 = 0.7200000000000001m
# t17 = 1.7000000000000004s
# x17 = 0.7650000000000001m
# t18 = 1.8000000000000005s
# x18 = 0.8100000000000002m
# t19 = 1.9000000000000006s
# x19 = 0.8550000000000002m
# t20 = 2.0000000000000004s
# x20 = 0.9000000000000002m
# t21 = 2.1000000000000005s
# x21 = 0.9450000000000003m
# ...

# %%
#v = 0.62 m/s, Where will the cart be at 2.2 seconds?
x = 0
t = 0
i = 0
v = 0.62
dt = 0.1

while t < 2.3:
    print("t{} = {}s".format(i, t))
    print("x{} = {}m".format(i, x))
    if t < 2.3:
        t += dt
        x += v*dt
        i += 1
    elif t >= 2.3:
        break
# Out:
# t0 = 0s
# x0 = 0m
# t1 = 0.1s
# x1 = 0.062m
# t2 = 0.2s
# x2 = 0.124m
# t3 = 0.30000000000000004s
# x3 = 0.186m
# t4 = 0.4s
# x4 = 0.248m
# t5 = 0.5s
# x5 = 0.31m
# t6 = 0.6s
# x6 = 0.372m
# t7 = 0.7s
# x7 = 0.434m
# t8 = 0.7999999999999999s
# x8 = 0.496m
# t9 = 0.8999999999999999s
# x9 = 0.558m
# t10 = 0.9999999999999999s
# x10 = 0.6200000000000001m
# t11 = 1.0999999999999999s
# x11 = 0.6820000000000002m
# t12 = 1.2s
# x12 = 0.7440000000000002m
# t13 = 1.3s
# x13 = 0.8060000000000003m
# t14 = 1.4000000000000001s
# x14 = 0.8680000000000003m
# t15 = 1.5000000000000002s
# x15 = 0.9300000000000004m
# t16 = 1.6000000000000003s
# x16 = 0.9920000000000004m
# t17 = 1.7000000000000004s
# x17 = 1.0540000000000005m
# t18 = 1.8000000000000005s
# x18 = 1.1160000000000005m
# t19 = 1.9000000000000006s
# x19 = 1.1780000000000006m
# t20 = 2.0000000000000004s
# x20 = 1.2400000000000007m
# t21 = 2.1000000000000005s
# x21 = 1.3020000000000007m
# t22 = 2.2000000000000006s
# x22 = 1.3640000000000008m

# %%
#cart start at x = -0.5m, v = 0.62 m/s, Where will the cart be at 2.2 seconds?
x = -0.5
t = 0
i = 0
v = 0.62
dt = 0.1

while t < 2.3:
    print("t{} = {}s".format(i, t))
    print("x{} = {}m".format(i, x))
    if t < 2.3:
        t += dt
        x += v*dt
        i += 1
    elif t >= 2.3:
        break
# Out:
# t0 = 0s
# x0 = -0.5m
# t1 = 0.1s
# x1 = -0.438m
# t2 = 0.2s
# x2 = -0.376m
# t3 = 0.30000000000000004s
# x3 = -0.314m
# t4 = 0.4s
# x4 = -0.252m
# t5 = 0.5s
# x5 = -0.19m
# t6 = 0.6s
# x6 = -0.128m
# t7 = 0.7s
# x7 = -0.066m
# t8 = 0.7999999999999999s
# x8 = -0.0040000000000000036m
# t9 = 0.8999999999999999s
# x9 = 0.057999999999999996m
# t10 = 0.9999999999999999s
# x10 = 0.12m
# t11 = 1.0999999999999999s
# x11 = 0.182m
# t12 = 1.2s
# x12 = 0.244m
# t13 = 1.3s
# x13 = 0.306m
# t14 = 1.4000000000000001s
# x14 = 0.368m
# t15 = 1.5000000000000002s
# x15 = 0.43m
# t16 = 1.6000000000000003s
# x16 = 0.492m
# t17 = 1.7000000000000004s
# x17 = 0.554m
# t18 = 1.8000000000000005s
# x18 = 0.6160000000000001m
# t19 = 1.9000000000000006s
# x19 = 0.6780000000000002m
# t20 = 2.0000000000000004s
# x20 = 0.7400000000000002m
# t21 = 2.1000000000000005s
# x21 = 0.8020000000000003m
# t22 = 2.2000000000000006s
# x22 = 0.8640000000000003m

# %%
#x0 = 0m, t0 = 0s, v = 0.45m/s, a = 0.2m/s^2, where is the cart after 1.5s

x0 = 0
t0 = 0
t1 = 1.5
v0 = 0.45
a = 0.2

s = v0*t1 + (1/2)*a*t1**2
x = x0+s
print(x)
# Out:
# 0.9

# %%
#x0 = 0m, t0 = 0s, v = 0.45m/s, a = 0.2m/s^2, where is the cart after 1.5s
#Break it in to small steps, dt=0.25

x = 0
t = 0
v = 0.45
a = 0.2
dt = 0.25
i = 0

while t <= 1.5:
    print("t{} = {} s".format(i, t))
    print("x{} = {} m".format(i, x))
    print("v{} = {} m/s".format(i, v))
    if t < 1.5:
        x = x + v*dt + (1/2)*a*dt**2
        t += dt
        v += a*dt
        i +=1
    else:
        break
# Out:
# t0 = 0 s
# x0 = 0 m
# v0 = 0.45 m/s
# t1 = 0.25 s
# x1 = 0.11875000000000001 m
# v1 = 0.5 m/s
# t2 = 0.5 s
# x2 = 0.25 m
# v2 = 0.55 m/s
# t3 = 0.75 s
# x3 = 0.39375 m
# v3 = 0.6000000000000001 m/s
# t4 = 1.0 s
# x4 = 0.5499999999999999 m
# v4 = 0.6500000000000001 m/s
# t5 = 1.25 s
# x5 = 0.7187499999999999 m
# v5 = 0.7000000000000002 m/s
# t6 = 1.5 s
# x6 = 0.8999999999999999 m
# v6 = 0.7500000000000002 m/s

# %%
#x0 = 0m, t0 = 0s, v = 0.45m/s, a = 0.2m/s^2, where is the cart after 1.5s
#Break it in to small steps,dt=0.01 

x = 0
t = 0
v = 0.45
a = 0.2
dt = 0.01
i = 0

while t <= 1.5:
    print("t{} = {} s".format(i, t))
    print("x{} = {} m".format(i, x))
    print("v{} = {} m/s".format(i, v))
    if t < 1.5:
        x = x + v*dt + (1/2)*a*dt**2
        t += dt
        v += a*dt
        i +=1
    else:
        break
# Out:
# t0 = 0 s
# x0 = 0 m
# v0 = 0.45 m/s
# t1 = 0.01 s
# x1 = 0.00451 m
# v1 = 0.452 m/s
# t2 = 0.02 s
# x2 = 0.00904 m
# v2 = 0.454 m/s
# t3 = 0.03 s
# x3 = 0.01359 m
# v3 = 0.456 m/s
# t4 = 0.04 s
# x4 = 0.01816 m
# v4 = 0.458 m/s
# t5 = 0.05 s
# x5 = 0.02275 m
# v5 = 0.46 m/s
# t6 = 0.060000000000000005 s
# x6 = 0.02736 m
# v6 = 0.462 m/s
# t7 = 0.07 s
# x7 = 0.031990000000000005 m
# v7 = 0.464 m/s
# t8 = 0.08 s
# x8 = 0.036640000000000006 m
# v8 = 0.466 m/s
# t9 = 0.09 s
# x9 = 0.041310000000000006 m
# v9 = 0.468 m/s
# t10 = 0.09999999999999999 s
# x10 = 0.046000000000000006 m
# v10 = 0.47000000000000003 m/s
# t11 = 0.10999999999999999 s
# x11 = 0.05071000000000001 m
# v11 = 0.47200000000000003 m/s
# t12 = 0.11999999999999998 s
# x12 = 0.05544000000000002 m
# v12 = 0.47400000000000003 m/s
# t13 = 0.12999999999999998 s
# x13 = 0.06019000000000002 m
# v13 = 0.47600000000000003 m/s
# t14 = 0.13999999999999999 s
# x14 = 0.06496000000000002 m
# v14 = 0.47800000000000004 m/s
# t15 = 0.15 s
# ...

# %%
#x0 = 0m, t0 = 0s, v = 0.45m/s, a = -0.01m/s^2, where is the cart after 1.5s
#Break it in to small steps,dt=0.1

x = 0
t = 0
v = 0.45
a = -0.01
dt = 0.1
i = 0

while v >= 0:
    print("t{} = {} s".format(i, t))
    print("x{} = {} m".format(i, x))
    print("v{} = {} m/s".format(i, v))
    if v >0:
        x = x + v*dt + (1/2)*a*dt**2
        t += dt
        v += a*dt
        i +=1
    else:
        break
# Out:
# t0 = 0 s
# x0 = 0 m
# v0 = 0.45 m/s
# t1 = 0.1 s
# x1 = 0.044950000000000004 m
# v1 = 0.449 m/s
# t2 = 0.2 s
# x2 = 0.08980000000000002 m
# v2 = 0.448 m/s
# t3 = 0.30000000000000004 s
# x3 = 0.13455000000000003 m
# v3 = 0.447 m/s
# t4 = 0.4 s
# x4 = 0.17920000000000003 m
# v4 = 0.446 m/s
# t5 = 0.5 s
# x5 = 0.22375000000000003 m
# v5 = 0.445 m/s
# t6 = 0.6 s
# x6 = 0.26820000000000005 m
# v6 = 0.444 m/s
# t7 = 0.7 s
# x7 = 0.31255000000000005 m
# v7 = 0.443 m/s
# t8 = 0.7999999999999999 s
# x8 = 0.35680000000000006 m
# v8 = 0.442 m/s
# t9 = 0.8999999999999999 s
# x9 = 0.4009500000000001 m
# v9 = 0.441 m/s
# t10 = 0.9999999999999999 s
# x10 = 0.44500000000000006 m
# v10 = 0.44 m/s
# t11 = 1.0999999999999999 s
# x11 = 0.48895000000000005 m
# v11 = 0.439 m/s
# t12 = 1.2 s
# x12 = 0.5328 m
# v12 = 0.438 m/s
# t13 = 1.3 s
# x13 = 0.57655 m
# v13 = 0.437 m/s
# t14 = 1.4000000000000001 s
# x14 = 0.6202 m
# v14 = 0.436 m/s
# t15 = 1.5000000000000002 s
# x15 = 0.66375 m
# v15 = 0.435 m/s
# ...

# %%
#x0 = 0m, t0 = 0s, v = 0.45m/s, a = -0.02m/s^2, where is the cart after 1.5s
#Break it in to small steps,dt=0.01

x = 0
t = 0
v = 0.45
a = -0.02
dt = 0.01
i = 0

while v >= 0:
    print("t{} = {} s".format(i, t))
    print("x{} = {} m".format(i, x))
    print("v{} = {} m/s".format(i, v))
    if v >0:
        x = x + v*dt + (1/2)*a*dt**2
        t += dt
        v += a*dt
        i +=1
    else:
        break
# Out:
# t0 = 0 s
# x0 = 0 m
# v0 = 0.45 m/s
# t1 = 0.01 s
# x1 = 0.004499 m
# v1 = 0.44980000000000003 m/s
# t2 = 0.02 s
# x2 = 0.008996000000000002 m
# v2 = 0.44960000000000006 m/s
# t3 = 0.03 s
# x3 = 0.013491000000000005 m
# v3 = 0.4494000000000001 m/s
# t4 = 0.04 s
# x4 = 0.017984000000000003 m
# v4 = 0.4492000000000001 m/s
# t5 = 0.05 s
# x5 = 0.022475000000000002 m
# v5 = 0.4490000000000001 m/s
# t6 = 0.060000000000000005 s
# x6 = 0.026964000000000002 m
# v6 = 0.44880000000000014 m/s
# t7 = 0.07 s
# x7 = 0.031451 m
# v7 = 0.44860000000000017 m/s
# t8 = 0.08 s
# x8 = 0.035936 m
# v8 = 0.4484000000000002 m/s
# t9 = 0.09 s
# x9 = 0.040419000000000004 m
# v9 = 0.4482000000000002 m/s
# t10 = 0.09999999999999999 s
# x10 = 0.0449 m
# v10 = 0.44800000000000023 m/s
# t11 = 0.10999999999999999 s
# x11 = 0.049379000000000006 m
# v11 = 0.44780000000000025 m/s
# t12 = 0.11999999999999998 s
# x12 = 0.05385600000000001 m
# v12 = 0.4476000000000003 m/s
# t13 = 0.12999999999999998 s
# ...
